# %%
from datetime import date
import pandas as pd
import quandl
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import numpy as np
from tensorflow.keras import layers, Sequential,models
import tensorflow as tf

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
print(gpus)
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
start = date(2000,10,12)
end = date.today()
google_stock = pd.read_csv("./LBMA-GOLD.csv").dropna(axis=0)  # 缺失值处理
print(google_stock.shape)
google_stock
# Out:
# (1255, 2)
#          Date  USD (PM)
# 0     9/12/16   1324.60
# 1     9/13/16   1323.65
# 2     9/14/16   1321.75
# 3     9/15/16   1310.80
# 4     9/16/16   1308.35
# ...       ...       ...
# 1260   9/6/21   1821.60
# 1261   9/7/21   1802.15
# 1262   9/8/21   1786.00
# 1263   9/9/21   1788.25
# 1264  9/10/21   1794.60
#
# [1255 rows x 2 columns]

# %%
plt.figure(figsize=(16, 8))
plt.plot(google_stock['USD (PM)'])
plt.show()

# %% [markdown]
# ### 数据预处理

# %%
# 时间点长度
time_stamp = 10

# 划分训练集与验证集
google_stock = google_stock[['USD (PM)']]  #  'Volume'

train = google_stock[0:900 + time_stamp]
print(f"train.shape:{train.shape}")
valid = google_stock[900 + time_stamp:]
print(f"valid.shape:{valid.shape}")

# 归一化
scaler = MinMaxScaler(feature_range=(0, 1))  
scaled_data = scaler.fit_transform(train)
x_train, y_train = [], []


# 训练集
print(f"scaled_data.shape:{scaled_data.shape}")
print(f"scaled_data[0]:{scaled_data[0]}")
for i in range(time_stamp, len(train)):
    x_train.append(scaled_data[i - time_stamp:i])
    y_train.append(scaled_data[i, 0])

x_train, y_train = np.array(x_train), np.array(y_train)

# 验证集
scaled_data = scaler.fit_transform(valid)
x_valid, y_valid = [], []
for i in range(time_stamp, len(valid)):
    x_valid.append(scaled_data[i - time_stamp:i])
    y_valid.append(scaled_data[i, 0])

x_valid, y_valid = np.array(x_valid), np.array(y_valid)

# 总体数据集
scaled_data = scaler.fit_transform(google_stock)
x_total, y_total = [], []
for i in range(time_stamp, len(google_stock)):
    x_total.append(scaled_data[i - time_stamp:i])
    y_total.append(scaled_data[i, 0])

x_total, y_total = np.array(x_total), np.array(y_total)

print(f"x_train.shape:{x_train.shape}")
print(f"x_valid.shape{x_valid.shape}")
print(f"x_total.shape:{x_total.shape}")
train.head()
# Out:
# train.shape:(910, 1)
# valid.shape:(345, 1)
# scaled_data.shape:(910, 1)
# scaled_data[0]:[0.32278481]
# x_train.shape:(900, 10, 1)
# x_valid.shape(335, 10, 1)
# x_total.shape:(1245, 10, 1)
#    USD (PM)
# 0   1324.60
# 1   1323.65
# 2   1321.75
# 3   1310.80
# 4   1308.35

# %% [markdown]
# ### 模型构建

# %%
# 超参数
epochs = 30
batch_size = 16
# LSTM 参数: return_sequences=True LSTM输出为一个序列。默认为False，输出一个值。
# input_dim： 输入单个样本特征值的维度
# input_length： 输入的时间点长度
model = Sequential()
model.add(layers.LSTM(units=100, return_sequences=True, input_dim=x_train.shape[-1], input_length=x_train.shape[1]))
model.add(layers.LSTM(units=50))
model.add(layers.Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 10, 100)           40800
#
#  lstm_1 (LSTM)               (None, 50)                30200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 71,051
# Trainable params: 71,051
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, verbose=1)
# Out:
# Epoch 1/30
# 57/57 [==============================] - 6s 7ms/step - loss: 0.0111
# Epoch 2/30
# 57/57 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 3/30
# 57/57 [==============================] - 0s 6ms/step - loss: 0.0017
# Epoch 4/30
# 57/57 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 5/30
# 57/57 [==============================] - 0s 7ms/step - loss: 0.0019
# Epoch 6/30
# 57/57 [==============================] - 0s 6ms/step - loss: 0.0014
# Epoch 7/30
# 57/57 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 8/30
# 57/57 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 9/30
# 57/57 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 10/30
# 57/57 [==============================] - 0s 7ms/step - loss: 0.0013
# Epoch 11/30
# 57/57 [==============================] - 0s 7ms/step - loss: 0.0011
# Epoch 12/30
# 57/57 [==============================] - 0s 7ms/step - loss: 0.0011
# Epoch 13/30
# 57/57 [==============================] - 0s 7ms/step - loss: 0.0010
# Epoch 14/30
# 57/57 [==============================] - 0s 7ms/step - loss: 9.9442e-04
# Epoch 15/30
# 57/57 [==============================] - 0s 7ms/step - loss: 0.0010
# Epoch 16/30
# 57/57 [==============================] - 0s 7ms/step - loss: 8.6329e-04
# Epoch 17/30
# 57/57 [==============================] - 0s 7ms/step - loss: 9.2246e-04
# Epoch 18/30
# 57/57 [==============================] - 0s 7ms/step - loss: 9.7693e-04
# Epoch 19/30
# 57/57 [==============================] - 0s 7ms/step - loss: 7.2979e-04
# Epoch 20/30
# 57/57 [==============================] - 0s 7ms/step - loss: 8.0707e-04
# Epoch 21/30
# 57/57 [==============================] - 1s 9ms/step - loss: 7.7329e-04
# Epoch 22/30
# 57/57 [==============================] - 0s 7ms/step - loss: 6.7041e-04
# Epoch 23/30
# 57/57 [==============================] - 0s 7ms/step - loss: 7.0033e-04
# Epoch 24/30
# 57/57 [==============================] - 0s 7ms/step - loss: 5.9323e-04
# Epoch 25/30
# 57/57 [==============================] - 0s 7ms/step - loss: 5.4901e-04
# Epoch 26/30
# 57/57 [==============================] - 0s 8ms/step - loss: 6.3187e-04
# Epoch 27/30
# 57/57 [==============================] - 0s 7ms/step - loss: 4.8413e-04
# Epoch 28/30
# 57/57 [==============================] - 0s 7ms/step - loss: 4.8004e-04
# Epoch 29/30
# 57/57 [==============================] - 0s 8ms/step - loss: 4.7781e-04
# Epoch 30/30
# 57/57 [==============================] - 0s 7ms/step - loss: 5.4504e-04

# %%
model.save("LBMA-GOLD.h5")

# %%
train_loss = history.history["loss"]


plt.plot(train_loss,label="train_loss")
plt.legend()
plt.xlabel("epochs")
plt.ylabel("loss")
plt.savefig("../../loss_g.png")
plt.show()

# %% [markdown]
# ### 测试集预测

# %%
x_valid_predict = model.predict(x_valid)
print(f"x_valid_predict.shape:{x_valid_predict.shape}")
scaler.fit_transform(pd.DataFrame(valid['USD (PM)'].values))
# 反归一化
x_valid_predict = scaler.inverse_transform(x_valid_predict)
y_valid = scaler.inverse_transform([y_valid])
rms = np.sqrt(np.mean(np.power((y_valid - x_valid_predict), 2)))
print(f"test_rms:{rms}")
print(f"x_valid_predict.shape:{x_valid_predict.shape}")
print(f"y_valid.shape{y_valid.shape}")
# Out:
# x_valid_predict.shape:(335, 1)
# test_rms:107.15202645881287
# x_valid_predict.shape:(335, 1)
# y_valid.shape(1, 335)

# %%
plt.plot(x_valid_predict.reshape(1,-1)[0],label="fitting value")
plt.plot(y_valid[0],label="true value")
plt.xlabel("time")
plt.ylabel("U.S. dollars per troy ounce")
plt.legend()
plt.savefig("../../fitting_g_test.png")
plt.show()

# %%
plt.figure(figsize=(16, 8))
dict_data = {
    'Predictions': x_valid_predict.reshape(1,-1)[0],
    'USD (PM)': y_valid[0]
}
data_pd = pd.DataFrame(dict_data)

plt.plot(data_pd[['USD (PM)', 'Predictions']])
plt.show()

# %% [markdown]
# ### 整体数据集上预测

# %%
x_total_predict = model.predict(x_total)

scaler.fit_transform(pd.DataFrame(google_stock['USD (PM)'].values))
# 反归一化
x_total_predict = scaler.inverse_transform(x_total_predict)
y_total = scaler.inverse_transform([y_total])
rms = np.sqrt(np.mean(np.power((y_total - x_total_predict), 2)))
print(f"test_rms:{rms}")
print(f"x_total_predict.shape:{x_total_predict.shape}")
print(f"y_total.shape{y_total.shape}")
# Out:
# test_rms:352.66993777869044
# x_total_predict.shape:(1245, 1)
# y_total.shape(1, 1245)

# %%
plt.figure(figsize=(16, 8))
dict_data = {
    'Predictions': x_total_predict.reshape(1,-1)[0],
    'USD (PM)': y_total[0]
}
data_pd = pd.DataFrame(dict_data)

plt.plot(data_pd[['USD (PM)', 'Predictions']])

plt.show()

# %%
plt.plot(x_total_predict.reshape(1,-1)[0],label="fitting value")
plt.plot(y_total[0],label="true value")
plt.xlabel("time")
plt.ylabel("U.S. dollars per troy ounce")
plt.legend()
plt.savefig("../../fitting_g.png")
plt.show()

# %% [markdown]
# ### 黄金的预测值保存和缺失值填充

# %%
predict = np.array([0 for i in range(30)] + list(x_total_predict[:,0]))
print(f"predict.shape:{predict.shape}")
df = pd.read_csv("./LBMA-GOLD.csv")
null_index = np.where(np.isnan(df['USD (PM)']))[0]
print(f"缺失值索引:{null_index}")

usd_predict = list(predict)
for index in null_index:
    usd_predict.insert(index,0.0)
    df.iloc[index,1] = 0.0
df["usd_nextday_predict"] = usd_predict
df.to_csv("黄金预测数据.csv",index=False)
# Out:
# predict.shape:(1255,)
# 缺失值索引:[  74   77  326  329  579  582  832  835 1086 1089]

# %%
df
# Out:
#          Date  USD (PM)  usd_nextday_predict
# 0     9/12/16   1324.60             0.000000
# 1     9/13/16   1323.65             0.000000
# 2     9/14/16   1321.75             0.000000
# 3     9/15/16   1310.80             0.000000
# 4     9/16/16   1308.35             0.000000
# ...       ...       ...                  ...
# 1260   9/6/21   1821.60          1828.734863
# 1261   9/7/21   1802.15          1830.250000
# 1262   9/8/21   1786.00          1817.861938
# 1263   9/9/21   1788.25          1800.261963
# 1264  9/10/21   1794.60          1794.274292
#
# [1265 rows x 3 columns]

# %% [markdown]
# ### 预测的黄金模型去预测比特币

# %%
start = date(2000,10,12)
end = date.today()
google_stock = pd.read_csv("./BCHAIN-MKPRU.csv").dropna(axis=0)
print(google_stock.shape)
google_stock
# Out:
# (1826, 2)
#          Date     Value
# 0     9/11/16    621.65
# 1     9/12/16    609.67
# 2     9/13/16    610.92
# 3     9/14/16    608.82
# 4     9/15/16    610.38
# ...       ...       ...
# 1821   9/6/21  51769.06
# 1822   9/7/21  52677.40
# 1823   9/8/21  46809.17
# 1824   9/9/21  46078.38
# 1825  9/10/21  46368.69
#
# [1826 rows x 2 columns]

# %%
plt.figure(figsize=(16, 8))
plt.plot(google_stock['Value'])
plt.show()

# %%
# 时间点长度
time_stamp = 30

# 划分训练集与验证集
google_stock = google_stock[['Value']]  #  'Volume'

train = google_stock[0:1700 + time_stamp]
print(f"train.shape:{train.shape}")
valid = google_stock[1700 + time_stamp:]

# 归一化
scaler = MinMaxScaler(feature_range=(0, 1))  
scaled_data = scaler.fit_transform(train)
x_train, y_train = [], []


# 训练集
print(scaled_data.shape)
print(scaled_data[1, 0])
for i in range(time_stamp, len(train)):
    x_train.append(scaled_data[i - time_stamp:i])
    y_train.append(scaled_data[i, 0])

x_train, y_train = np.array(x_train), np.array(y_train)

# 验证集
scaled_data = scaler.fit_transform(valid)
x_valid, y_valid = [], []
for i in range(time_stamp, len(valid)):
    x_valid.append(scaled_data[i - time_stamp:i])
    y_valid.append(scaled_data[i, 0])

x_valid, y_valid = np.array(x_valid), np.array(y_valid)

print(x_train.shape)
print(x_valid.shape)
train.head()
# Out:
# train.shape:(1730, 1)
# (1730, 1)
# 0.00024761611909461696
# (1700, 30, 1)
# (66, 30, 1)
#     Value
# 0  621.65
# 1  609.67
# 2  610.92
# 3  608.82
# 4  610.38

# %% [markdown]
# ### 测试集预测

# %%
x_valid_predict = model.predict(x_valid)
scaler.fit_transform(pd.DataFrame(valid['Value'].values))
# 反归一化
x_valid_predict = scaler.inverse_transform(x_valid_predict)
y_valid = scaler.inverse_transform([y_valid])
# print(y_valid)
# print(closing_price)
rms = np.sqrt(np.mean(np.power((y_valid - x_valid_predict), 2)))
print(f"test_rms:{rms}")
print(x_valid_predict.shape)
print(y_valid.shape)
# Out:
# test_rms:9637.836607857284
# (66, 1)
# (1, 66)

# %%
plt.figure(figsize=(16, 8))
dict_data = {
    'Predictions': x_valid_predict.reshape(1,-1)[0],
    'Value': y_valid[0]
}
data_pd = pd.DataFrame(dict_data)

plt.plot(data_pd[['Value', 'Predictions']])
plt.show()

# %% [markdown]
# ### 总体数据预测

# %%
x_train_predict = model.predict(x_train)
scaler.fit_transform(pd.DataFrame(train['Value'].values))
# 反归一化
x_train_predict = scaler.inverse_transform(x_train_predict)
y_train = scaler.inverse_transform([y_train])
# print(y_valid)
# print(closing_price)
train_rms = np.sqrt(np.mean(np.power((y_train - x_train_predict), 2)))
print(f"train_rms:{train_rms}")
print(x_train_predict.shape)
print(y_train.shape)
# Out:
# train_rms:18150.230769966613
# (1700, 1)
# (1, 1700)

# %%
plt.figure(figsize=(16, 8))
dict_data = {
    'Predictions': list(x_train_predict.reshape(1,-1)[0]) + list(x_valid_predict.reshape(1,-1)[0]),
    'USD (PM)': list(y_train[0]) + list(y_valid[0])
}
data_pd = pd.DataFrame(dict_data)

plt.plot(data_pd[['USD (PM)', 'Predictions']])
plt.show()
